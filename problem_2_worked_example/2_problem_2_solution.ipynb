# %%
import os

def identify_files_with_fewer_values(folder_path, expected_values=100):
    """
    To identify sample files in the specified folder that have fewer than the expected number of values.
    
    Parameters:
    - folder_path (str): The path to the folder containing the sample files.
    - expected_values (int): The expected number of values per sample file.
    """
    # List all files in the specified folder and iterate through each file
    files = os.listdir(folder_path)

    for file_name in files:
        file_path = os.path.join(folder_path, file_name)

        # Check if it's a file (not a directory)
        if os.path.isfile(file_path):
            # Open the file and count the number of lines (values)
            with open(file_path, 'r') as file:
                num_values = sum(1 for line in file)

            # Check if the number of values is less than the expected
            if num_values < expected_values:
                print(f"This file '{file_name}' has {num_values} but the values should be:{expected_values}.")

# %%
# Example usage
folder_path = 'C:/Users/<myUsername>/Documents/Python_Scripts/rseprac-master/problem_2_worked_examples/'  # Replace with the username your sample files
identify_files_with_fewer_values(folder_path)
# Out:
# This file 'values1' has 1 but the values should be:100.
# This file 'values10' has 1 but the values should be:100.
# This file 'values100' has 1 but the values should be:100.
# This file 'values101' has 1 but the values should be:100.
# This file 'values102' has 1 but the values should be:100.
# This file 'values103' has 1 but the values should be:100.
# This file 'values104' has 1 but the values should be:100.
# This file 'values105' has 1 but the values should be:100.
# This file 'values106' has 1 but the values should be:100.
# This file 'values107' has 1 but the values should be:100.
# This file 'values108' has 1 but the values should be:100.
# This file 'values109' has 1 but the values should be:100.
# This file 'values11' has 1 but the values should be:100.
# This file 'values110' has 1 but the values should be:100.
# This file 'values111' has 1 but the values should be:100.
# This file 'values112' has 1 but the values should be:100.
# This file 'values113' has 1 but the values should be:100.
# This file 'values114' has 1 but the values should be:100.
# This file 'values115' has 1 but the values should be:100.
# This file 'values116' has 1 but the values should be:100.
# This file 'values117' has 1 but the values should be:100.
# This file 'values118' has 1 but the values should be:100.
# This file 'values119' has 1 but the values should be:100.
# This file 'values12' has 1 but the values should be:100.
# This file 'values120' has 1 but the values should be:100.
# This file 'values121' has 1 but the values should be:100.
# This file 'values122' has 1 but the values should be:100.
# This file 'values123' has 1 but the values should be:100.
# This file 'values124' has 1 but the values should be:100.
# This file 'values125' has 1 but the values should be:100.
# This file 'values126' has 1 but the values should be:100.
# This file 'values127' has 1 but the values should be:100.
# This file 'values128' has 1 but the values should be:100.
# This file 'values129' has 1 but the values should be:100.
# This file 'values13' has 1 but the values should be:100.
# This file 'values130' has 1 but the values should be:100.
# This file 'values131' has 1 but the values should be:100.
# This file 'values132' has 1 but the values should be:100.
# This file 'values133' has 1 but the values should be:100.
# This file 'values134' has 1 but the values should be:100.
# This file 'values135' has 1 but the values should be:100.
# This file 'values136' has 1 but the values should be:100.
# This file 'values137' has 1 but the values should be:100.
# This file 'values138' has 1 but the values should be:100.
# This file 'values139' has 1 but the values should be:100.
# This file 'values14' has 1 but the values should be:100.
# This file 'values140' has 1 but the values should be:100.
# This file 'values141' has 1 but the values should be:100.
# This file 'values142' has 1 but the values should be:100.
# This file 'values143' has 1 but the values should be:100.
# This file 'values144' has 1 but the values should be:100.
# This file 'values145' has 1 but the values should be:100.
# This file 'values146' has 1 but the values should be:100.
# This file 'values147' has 1 but the values should be:100.
# This file 'values148' has 1 but the values should be:100.
# This file 'values149' has 1 but the values should be:100.
# This file 'values15' has 1 but the values should be:100.
# This file 'values150' has 1 but the values should be:100.
# This file 'values151' has 1 but the values should be:100.
# This file 'values152' has 1 but the values should be:100.
# This file 'values153' has 1 but the values should be:100.
# This file 'values154' has 1 but the values should be:100.
# This file 'values155' has 1 but the values should be:100.
# This file 'values156' has 1 but the values should be:100.
# This file 'values157' has 1 but the values should be:100.
# This file 'values158' has 1 but the values should be:100.
# This file 'values159' has 1 but the values should be:100.
# This file 'values16' has 1 but the values should be:100.
# This file 'values160' has 1 but the values should be:100.
# This file 'values161' has 1 but the values should be:100.
# This file 'values162' has 1 but the values should be:100.
# This file 'values163' has 1 but the values should be:100.
# This file 'values164' has 1 but the values should be:100.
# This file 'values165' has 1 but the values should be:100.
# This file 'values166' has 1 but the values should be:100.
# This file 'values167' has 1 but the values should be:100.
# This file 'values168' has 1 but the values should be:100.
# This file 'values169' has 1 but the values should be:100.
# This file 'values17' has 1 but the values should be:100.
# This file 'values170' has 1 but the values should be:100.
# This file 'values171' has 1 but the values should be:100.
# This file 'values172' has 1 but the values should be:100.
# This file 'values173' has 1 but the values should be:100.
# This file 'values174' has 1 but the values should be:100.
# This file 'values175' has 1 but the values should be:100.
# This file 'values176' has 1 but the values should be:100.
# This file 'values177' has 1 but the values should be:100.
# This file 'values178' has 1 but the values should be:100.
# This file 'values179' has 1 but the values should be:100.
# This file 'values18' has 1 but the values should be:100.
# This file 'values180' has 1 but the values should be:100.
# This file 'values181' has 1 but the values should be:100.
# This file 'values182' has 1 but the values should be:100.
# This file 'values183' has 1 but the values should be:100.
# This file 'values184' has 1 but the values should be:100.
# This file 'values185' has 1 but the values should be:100.
# This file 'values186' has 1 but the values should be:100.
# This file 'values187' has 1 but the values should be:100.
# This file 'values188' has 1 but the values should be:100.
# This file 'values189' has 1 but the values should be:100.
# This file 'values19' has 1 but the values should be:100.
# This file 'values190' has 1 but the values should be:100.
# This file 'values191' has 1 but the values should be:100.
# This file 'values192' has 1 but the values should be:100.
# This file 'values193' has 1 but the values should be:100.
# This file 'values194' has 1 but the values should be:100.
# This file 'values195' has 1 but the values should be:100.
# This file 'values196' has 1 but the values should be:100.
# This file 'values197' has 1 but the values should be:100.
# This file 'values198' has 1 but the values should be:100.
# This file 'values199' has 1 but the values should be:100.
# This file 'values2' has 1 but the values should be:100.
# This file 'values20' has 1 but the values should be:100.
# This file 'values200' has 1 but the values should be:100.
# This file 'values201' has 1 but the values should be:100.
# This file 'values202' has 1 but the values should be:100.
# This file 'values203' has 1 but the values should be:100.
# This file 'values204' has 1 but the values should be:100.
# This file 'values205' has 1 but the values should be:100.
# This file 'values206' has 1 but the values should be:100.
# This file 'values207' has 1 but the values should be:100.
# This file 'values208' has 1 but the values should be:100.
# This file 'values209' has 1 but the values should be:100.
# This file 'values21' has 1 but the values should be:100.
# This file 'values210' has 1 but the values should be:100.
# This file 'values211' has 1 but the values should be:100.
# This file 'values212' has 1 but the values should be:100.
# This file 'values213' has 1 but the values should be:100.
# This file 'values214' has 1 but the values should be:100.
# This file 'values215' has 1 but the values should be:100.
# This file 'values216' has 1 but the values should be:100.
# This file 'values217' has 1 but the values should be:100.
# This file 'values218' has 1 but the values should be:100.
# This file 'values219' has 1 but the values should be:100.
# This file 'values22' has 1 but the values should be:100.
# This file 'values220' has 1 but the values should be:100.
# This file 'values221' has 1 but the values should be:100.
# This file 'values222' has 1 but the values should be:100.
# This file 'values223' has 1 but the values should be:100.
# This file 'values224' has 1 but the values should be:100.
# This file 'values225' has 1 but the values should be:100.
# This file 'values226' has 1 but the values should be:100.
# This file 'values227' has 1 but the values should be:100.
# This file 'values228' has 1 but the values should be:100.
# This file 'values229' has 1 but the values should be:100.
# This file 'values23' has 1 but the values should be:100.
# This file 'values230' has 1 but the values should be:100.
# This file 'values231' has 1 but the values should be:100.
# This file 'values232' has 1 but the values should be:100.
# This file 'values233' has 1 but the values should be:100.
# This file 'values234' has 1 but the values should be:100.
# This file 'values235' has 1 but the values should be:100.
# This file 'values236' has 1 but the values should be:100.
# This file 'values237' has 1 but the values should be:100.
# This file 'values238' has 1 but the values should be:100.
# This file 'values239' has 1 but the values should be:100.
# This file 'values24' has 1 but the values should be:100.
# This file 'values240' has 1 but the values should be:100.
# This file 'values241' has 1 but the values should be:100.
# This file 'values242' has 1 but the values should be:100.
# This file 'values243' has 1 but the values should be:100.
# This file 'values244' has 1 but the values should be:100.
# This file 'values245' has 1 but the values should be:100.
# This file 'values246' has 1 but the values should be:100.
# This file 'values247' has 1 but the values should be:100.
# This file 'values248' has 1 but the values should be:100.
# This file 'values249' has 1 but the values should be:100.
# This file 'values25' has 1 but the values should be:100.
# This file 'values250' has 1 but the values should be:100.
# This file 'values251' has 1 but the values should be:100.
# This file 'values252' has 1 but the values should be:100.
# This file 'values253' has 1 but the values should be:100.
# This file 'values254' has 1 but the values should be:100.
# This file 'values255' has 1 but the values should be:100.
# This file 'values256' has 1 but the values should be:100.
# This file 'values257' has 1 but the values should be:100.
# This file 'values258' has 1 but the values should be:100.
# This file 'values259' has 1 but the values should be:100.
# This file 'values26' has 1 but the values should be:100.
# This file 'values260' has 1 but the values should be:100.
# This file 'values261' has 1 but the values should be:100.
# This file 'values262' has 1 but the values should be:100.
# This file 'values263' has 1 but the values should be:100.
# This file 'values264' has 1 but the values should be:100.
# This file 'values265' has 1 but the values should be:100.
# This file 'values266' has 1 but the values should be:100.
# This file 'values267' has 1 but the values should be:100.
# This file 'values268' has 1 but the values should be:100.
# This file 'values269' has 1 but the values should be:100.
# This file 'values27' has 1 but the values should be:100.
# This file 'values270' has 1 but the values should be:100.
# This file 'values271' has 1 but the values should be:100.
# This file 'values272' has 1 but the values should be:100.
# This file 'values273' has 1 but the values should be:100.
# This file 'values274' has 1 but the values should be:100.
# This file 'values275' has 1 but the values should be:100.
# This file 'values276' has 1 but the values should be:100.
# This file 'values277' has 1 but the values should be:100.
# This file 'values278' has 1 but the values should be:100.
# This file 'values279' has 1 but the values should be:100.
# This file 'values28' has 1 but the values should be:100.
# This file 'values280' has 1 but the values should be:100.
# This file 'values281' has 1 but the values should be:100.
# This file 'values282' has 1 but the values should be:100.
# This file 'values283' has 1 but the values should be:100.
# This file 'values284' has 1 but the values should be:100.
# This file 'values285' has 1 but the values should be:100.
# This file 'values286' has 1 but the values should be:100.
# This file 'values287' has 1 but the values should be:100.
# This file 'values288' has 1 but the values should be:100.
# This file 'values289' has 1 but the values should be:100.
# This file 'values29' has 1 but the values should be:100.
# This file 'values290' has 1 but the values should be:100.
# This file 'values291' has 1 but the values should be:100.
# This file 'values292' has 1 but the values should be:100.
# This file 'values293' has 1 but the values should be:100.
# This file 'values294' has 1 but the values should be:100.
# This file 'values295' has 1 but the values should be:100.
# This file 'values296' has 1 but the values should be:100.
# This file 'values297' has 1 but the values should be:100.
# This file 'values298' has 1 but the values should be:100.
# This file 'values299' has 1 but the values should be:100.
# This file 'values3' has 1 but the values should be:100.
# This file 'values30' has 1 but the values should be:100.
# This file 'values31' has 1 but the values should be:100.
# This file 'values32' has 1 but the values should be:100.
# This file 'values33' has 1 but the values should be:100.
# This file 'values34' has 1 but the values should be:100.
# This file 'values35' has 1 but the values should be:100.
# This file 'values36' has 1 but the values should be:100.
# This file 'values37' has 1 but the values should be:100.
# This file 'values38' has 1 but the values should be:100.
# This file 'values39' has 1 but the values should be:100.
# This file 'values4' has 1 but the values should be:100.
# This file 'values40' has 1 but the values should be:100.
# This file 'values41' has 1 but the values should be:100.
# This file 'values42' has 1 but the values should be:100.
# This file 'values43' has 1 but the values should be:100.
# This file 'values44' has 1 but the values should be:100.
# This file 'values45' has 1 but the values should be:100.
# This file 'values46' has 1 but the values should be:100.
# This file 'values47' has 1 but the values should be:100.
# This file 'values48' has 1 but the values should be:100.
# This file 'values49' has 1 but the values should be:100.
# This file 'values5' has 1 but the values should be:100.
# This file 'values50' has 1 but the values should be:100.
# This file 'values51' has 1 but the values should be:100.
# This file 'values52' has 1 but the values should be:100.
# This file 'values53' has 1 but the values should be:100.
# This file 'values54' has 1 but the values should be:100.
# This file 'values55' has 1 but the values should be:100.
# This file 'values56' has 1 but the values should be:100.
# This file 'values57' has 1 but the values should be:100.
# This file 'values58' has 1 but the values should be:100.
# This file 'values59' has 1 but the values should be:100.
# This file 'values6' has 1 but the values should be:100.
# This file 'values60' has 1 but the values should be:100.
# This file 'values61' has 1 but the values should be:100.
# This file 'values62' has 1 but the values should be:100.
# This file 'values63' has 1 but the values should be:100.
# This file 'values64' has 1 but the values should be:100.
# This file 'values65' has 1 but the values should be:100.
# This file 'values66' has 1 but the values should be:100.
# This file 'values67' has 1 but the values should be:100.
# This file 'values68' has 1 but the values should be:100.
# This file 'values69' has 1 but the values should be:100.
# This file 'values7' has 1 but the values should be:100.
# This file 'values70' has 1 but the values should be:100.
# This file 'values71' has 1 but the values should be:100.
# This file 'values72' has 1 but the values should be:100.
# This file 'values73' has 1 but the values should be:100.
# This file 'values74' has 1 but the values should be:100.
# This file 'values75' has 1 but the values should be:100.
# This file 'values76' has 1 but the values should be:100.
# This file 'values77' has 1 but the values should be:100.
# This file 'values78' has 1 but the values should be:100.
# This file 'values79' has 1 but the values should be:100.
# This file 'values8' has 1 but the values should be:100.
# This file 'values80' has 1 but the values should be:100.
# This file 'values81' has 1 but the values should be:100.
# This file 'values82' has 1 but the values should be:100.
# This file 'values83' has 1 but the values should be:100.
# This file 'values84' has 1 but the values should be:100.
# This file 'values85' has 1 but the values should be:100.
# This file 'values86' has 1 but the values should be:100.
# This file 'values87' has 1 but the values should be:100.
# This file 'values88' has 1 but the values should be:100.
# This file 'values89' has 1 but the values should be:100.
# This file 'values9' has 1 but the values should be:100.
# This file 'values90' has 1 but the values should be:100.
# This file 'values91' has 1 but the values should be:100.
# This file 'values92' has 1 but the values should be:100.
# This file 'values93' has 1 but the values should be:100.
# This file 'values94' has 1 but the values should be:100.
# This file 'values95' has 1 but the values should be:100.
# This file 'values96' has 1 but the values should be:100.
# This file 'values97' has 1 but the values should be:100.
# This file 'values98' has 1 but the values should be:100.
# This file 'values99' has 1 but the values should be:100.
