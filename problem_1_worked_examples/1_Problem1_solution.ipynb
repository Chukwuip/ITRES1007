# %%
import os

def rename_files(folder_path, new_extension=".dat"):
    """
    Rename files in the specified folder with a new file extension.
    
    Parameters:
    - folder_path (str): The path to the folder containing the files.
    - new_extension (str): The new file extension to be used.
    """
    # List all files in the specified folder
    files = os.listdir(folder_path)

    # Iterate through each file
    for file_name in files:
        # Check if it's a file (not a directory)
        if os.path.isfile(os.path.join(folder_path, file_name)):
            # Split the file name and extension
            base_name, _ = os.path.splitext(file_name)

            # Rename the file with the new extension
            new_file_name = base_name + new_extension
            os.rename(os.path.join(folder_path, file_name), os.path.join(folder_path, new_file_name))
            print(f"Renamed: {file_name} to {new_file_name}")

# Example usage
folder_path = 'C:/Users/<myUsername>/Documents/Python_Scripts/rseprac-master/problem_1/'  
rename_files(folder_path)
# Out:
# Renamed: datafile1.dat to datafile1.dat
# Renamed: datafile10.dat to datafile10.dat
# Renamed: datafile100.dat to datafile100.dat
# Renamed: datafile11.dat to datafile11.dat
# Renamed: datafile12.dat to datafile12.dat
# Renamed: datafile13.dat to datafile13.dat
# Renamed: datafile14.dat to datafile14.dat
# Renamed: datafile15.dat to datafile15.dat
# Renamed: datafile16.dat to datafile16.dat
# Renamed: datafile17.dat to datafile17.dat
# Renamed: datafile18.dat to datafile18.dat
# Renamed: datafile19.dat to datafile19.dat
# Renamed: datafile2.dat to datafile2.dat
# Renamed: datafile20.dat to datafile20.dat
# Renamed: datafile21.dat to datafile21.dat
# Renamed: datafile22.dat to datafile22.dat
# Renamed: datafile23.dat to datafile23.dat
# Renamed: datafile24.dat to datafile24.dat
# Renamed: datafile25.dat to datafile25.dat
# Renamed: datafile26.dat to datafile26.dat
# Renamed: datafile27.dat to datafile27.dat
# Renamed: datafile28.dat to datafile28.dat
# Renamed: datafile29.dat to datafile29.dat
# Renamed: datafile3.dat to datafile3.dat
# Renamed: datafile30.dat to datafile30.dat
# Renamed: datafile31.dat to datafile31.dat
# Renamed: datafile32.dat to datafile32.dat
# Renamed: datafile33.dat to datafile33.dat
# Renamed: datafile34.dat to datafile34.dat
# Renamed: datafile35.dat to datafile35.dat
# Renamed: datafile36.dat to datafile36.dat
# Renamed: datafile37.dat to datafile37.dat
# Renamed: datafile38.dat to datafile38.dat
# Renamed: datafile39.dat to datafile39.dat
# Renamed: datafile4.dat to datafile4.dat
# Renamed: datafile40.dat to datafile40.dat
# Renamed: datafile41.dat to datafile41.dat
# Renamed: datafile42.dat to datafile42.dat
# Renamed: datafile43.dat to datafile43.dat
# Renamed: datafile44.dat to datafile44.dat
# Renamed: datafile45.dat to datafile45.dat
# Renamed: datafile46.dat to datafile46.dat
# Renamed: datafile47.dat to datafile47.dat
# Renamed: datafile48.dat to datafile48.dat
# Renamed: datafile49.dat to datafile49.dat
# Renamed: datafile5.dat to datafile5.dat
# Renamed: datafile50.dat to datafile50.dat
# Renamed: datafile51.dat to datafile51.dat
# Renamed: datafile52.dat to datafile52.dat
# Renamed: datafile53.dat to datafile53.dat
# Renamed: datafile54.dat to datafile54.dat
# Renamed: datafile55.dat to datafile55.dat
# Renamed: datafile56.dat to datafile56.dat
# Renamed: datafile57.dat to datafile57.dat
# Renamed: datafile58.dat to datafile58.dat
# Renamed: datafile59.dat to datafile59.dat
# Renamed: datafile6.dat to datafile6.dat
# Renamed: datafile60.dat to datafile60.dat
# Renamed: datafile61.dat to datafile61.dat
# Renamed: datafile62.dat to datafile62.dat
# Renamed: datafile63.dat to datafile63.dat
# Renamed: datafile64.dat to datafile64.dat
# Renamed: datafile65.dat to datafile65.dat
# Renamed: datafile66.dat to datafile66.dat
# Renamed: datafile67.dat to datafile67.dat
# Renamed: datafile68.dat to datafile68.dat
# Renamed: datafile69.dat to datafile69.dat
# Renamed: datafile7.dat to datafile7.dat
# Renamed: datafile70.dat to datafile70.dat
# Renamed: datafile71.dat to datafile71.dat
# Renamed: datafile72.dat to datafile72.dat
# Renamed: datafile73.dat to datafile73.dat
# Renamed: datafile74.dat to datafile74.dat
# Renamed: datafile75.dat to datafile75.dat
# Renamed: datafile76.dat to datafile76.dat
# Renamed: datafile77.dat to datafile77.dat
# Renamed: datafile78.dat to datafile78.dat
# Renamed: datafile79.dat to datafile79.dat
# Renamed: datafile8.dat to datafile8.dat
# Renamed: datafile80.dat to datafile80.dat
# Renamed: datafile81.dat to datafile81.dat
# Renamed: datafile82.dat to datafile82.dat
# Renamed: datafile83.dat to datafile83.dat
# Renamed: datafile84.dat to datafile84.dat
# Renamed: datafile85.dat to datafile85.dat
# Renamed: datafile86.dat to datafile86.dat
# Renamed: datafile87.dat to datafile87.dat
# Renamed: datafile88.dat to datafile88.dat
# Renamed: datafile89.dat to datafile89.dat
# Renamed: datafile9.dat to datafile9.dat
# Renamed: datafile90.dat to datafile90.dat
# Renamed: datafile91.dat to datafile91.dat
# Renamed: datafile92.dat to datafile92.dat
# Renamed: datafile93.dat to datafile93.dat
# Renamed: datafile94.dat to datafile94.dat
# Renamed: datafile95.dat to datafile95.dat
# Renamed: datafile96.dat to datafile96.dat
# Renamed: datafile97.dat to datafile97.dat
# Renamed: datafile98.dat to datafile98.dat
# Renamed: datafile99.dat to datafile99.dat
# Renamed: Untitled.dat to Untitled.dat
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[5], line 28
#      26 # Example usage
#      27 folder_path = 'C:/Users/medich/Documents/Python_Scripts/rseprac-master/problem_1/'  # Replace with the actual path to your data files
# ---> 28 rename_files(folder_path)
#
# Cell In[5], line 23, in rename_files(folder_path, new_extension)
#      21 # Rename the file with the new extension
#      22 new_file_name = base_name + new_extension
# ---> 23 os.rename(os.path.join(folder_path, file_name), os.path.join(folder_path, new_file_name))
#      24 print(f"Renamed: {file_name} to {new_file_name}")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:/Users/medich/Documents/Python_Scripts/rseprac-master/problem_1/Untitled.ipynb' -> 'C:/Users/medich/Documents/Python_Scripts/rseprac-master/problem_1/Untitled.dat'

# %%
# Example usage
folder_path = 'problem_1\'
rename_files(folder_path)
# Out:
#   Cell In[8], line 2
#     folder_path = 'problem_1\'
#                   ^
# SyntaxError: unterminated string literal (detected at line 2)
